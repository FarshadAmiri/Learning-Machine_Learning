# %%
import numpy as np
import pandas as pd
import re

# %%
df = pd.read_csv(r"C:\Users\famir\Desktop\Pokemon.csv")
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df[['Name','Attack','Type 1']]
# Out:
#                       Name  Attack   Type 1
# 0                Bulbasaur      49    Grass
# 1                  Ivysaur      62    Grass
# 2                 Venusaur      82    Grass
# 3    VenusaurMega Venusaur     100    Grass
# 4               Charmander      52     Fire
# ..                     ...     ...      ...
# 795                Diancie     100     Rock
# 796    DiancieMega Diancie     160     Rock
# 797    HoopaHoopa Confined     110  Psychic
# 798     HoopaHoopa Unbound     160  Psychic
# 799              Volcanion     110     Fire
#
# [800 rows x 3 columns]

# %%
df.iloc[1]['Name']
# Out:
# 'Ivysaur'

# %%
df.head(12)
# Out:
#     #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0   1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1   2                    Ivysaur  Grass  Poison    405  60      62       63
# 2   3                   Venusaur  Grass  Poison    525  80      82       83
# 3   3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4   4                 Charmander   Fire     NaN    309  39      52       43
# 5   5                 Charmeleon   Fire     NaN    405  58      64       58
# 6   6                  Charizard   Fire  Flying    534  78      84       78
# 7   6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8   6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9   7                   Squirtle  Water     NaN    314  44      48       65
# 10  8                  Wartortle  Water     NaN    405  59      63       80
# ...

# %%
df.index[745:750]
# Out:
# RangeIndex(start=745, stop=750, step=1)

# %%
df.loc[((df['HP']>80) & (df['Type 1'] == 'Fire'))]
# Out:
#        #                     Name Type 1    Type 2  Total   HP  Attack  \
# 64    59                 Arcanine   Fire       NaN    555   90     110
# 158  146                  Moltres   Fire    Flying    580   90     100
# 263  244                    Entei   Fire       NaN    580  115     115
# 270  250                    Ho-oh   Fire    Flying    680  106     130
# 542  485                  Heatran   Fire     Steel    600   91      90
# 558  499                  Pignite   Fire  Fighting    418   90      93
# 559  500                   Emboar   Fire  Fighting    528  110     123
# 615  555  DarmanitanStandard Mode   Fire       NaN    480  105     140
# 616  555       DarmanitanZen Mode   Fire   Psychic    540  105      30
# 692  631                  Heatmor   Fire       NaN    484   85      97
# 736  668                   Pyroar   Fire    Normal    507   86      68
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df_s1 = df.sort_values(['Generation', 'Attack'] , ascending = [1,0])
df_s1[0:10]
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 163  150        MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# 137  127          PinsirMega Pinsir       Bug    Flying    600   65     155
# 141  130      GyaradosMega Gyarados     Water      Dark    640   95     155
# 19    15      BeedrillMega Beedrill       Bug    Poison    495   65     150
# 164  150        MewtwoMega Mewtwo Y   Psychic       NaN    780  106     150
# 154  142  AerodactylMega Aerodactyl      Rock    Flying    615   80     135
# 161  149                  Dragonite    Dragon    Flying    600   91     134
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 74    68                    Machamp  Fighting       NaN    505   90     130
# 107   99                    Kingler     Water       NaN    475   55     130
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      100      154      100    130           1       True
# ...

# %%
df['Total Power'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] +df['Sp. Def'] + df['Speed']

# %%
df.sort_values(['Generation' , 'Total Power'], ascending = [1,0])
# Out:
#        #                       Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150        MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 164  150        MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 162  150                     Mewtwo  Psychic       NaN    680  106     110
# 141  130      GyaradosMega Gyarados    Water      Dark    640   95     155
# 7      6  CharizardMega Charizard X     Fire    Dragon    634   78     130
# ..   ...                        ...      ...       ...    ...  ...     ...
# 729  661                 Fletchling   Normal    Flying    278   45      50
# 790  714                     Noibat   Flying    Dragon    245   40      30
# 727  659                   Bunnelby   Normal       NaN    237   38      36
# 733  665                     Spewpa      Bug       NaN    213   45      22
# 732  664                 Scatterbug      Bug       NaN    200   38      35
#
# ...

# %%
df.loc[((df['Type 1'] == 'Fire') & (df['Total Power']>500))].sort_values('Total Power',ascending =False )
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 270  250                      Ho-oh   Fire    Flying    680  106     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 279  257      BlazikenMega Blaziken   Fire  Fighting    630   80     160
# 799  721                  Volcanion   Fire     Water    600   80     110
# 542  485                    Heatran   Fire     Steel    600   91      90
# 158  146                    Moltres   Fire    Flying    580   90     100
# 263  244                      Entei   Fire       NaN    580  115     115
# 354  323      CameruptMega Camerupt   Fire    Ground    560   70     120
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 518  467                  Magmortar   Fire       NaN    540   75      95
# 616  555         DarmanitanZen Mode   Fire   Psychic    540  105      30
# ...

# %%
df = df.drop(columns='Total')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total Power
# ...

# %%
cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]] + cols[4:-1]]
df
# Out:
#        #                   Name   Type 1  Type 2  Total Power  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison          318  45      49
# 1      2                Ivysaur    Grass  Poison          405  60      62
# 2      3               Venusaur    Grass  Poison          525  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison          625  80     100
# 4      4             Charmander     Fire     NaN          309  39      52
# ..   ...                    ...      ...     ...          ...  ..     ...
# 795  719                Diancie     Rock   Fairy          600  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy          700  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost          600  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark          680  80     160
# 799  721              Volcanion     Fire   Water          600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.to_csv(r"C:\Users\famir\Desktop\Pokemon_m1.csv" , index=False)

# %%
TP = df['Total Power']

# %%
type(TP)
# Out:
# pandas.core.series.Series

# %%
df_f1 = df.loc[(df['Type 1']=='Fire') | (df['Total Power']>700)]

# %%
df_f1.reset_index(drop=True,inplace=True)

# %%
df_f1
# Out:
#       #                       Name   Type 1    Type 2  Total Power   HP  \
# 0     4                 Charmander     Fire       NaN          309   39
# 1     5                 Charmeleon     Fire       NaN          405   58
# 2     6                  Charizard     Fire    Flying          534   78
# 3     6  CharizardMega Charizard X     Fire    Dragon          634   78
# 4     6  CharizardMega Charizard Y     Fire    Flying          634   78
# 5    37                     Vulpix     Fire       NaN          299   38
# 6    38                  Ninetales     Fire       NaN          505   73
# 7    58                  Growlithe     Fire       NaN          350   55
# 8    59                   Arcanine     Fire       NaN          555   90
# 9    77                     Ponyta     Fire       NaN          410   50
# 10   78                   Rapidash     Fire       NaN          500   65
# 11  126                     Magmar     Fire       NaN          495   65
# ...

# %%
df.loc[df['Type 1']=='Green' , 'Type 2']='Green_2'

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total Power  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison          318  45      49
# 1      2                Ivysaur    Grass  Poison          405  60      62
# 2      3               Venusaur    Grass  Poison          525  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison          625  80     100
# 4      4             Charmander     Fire     NaN          309  39      52
# ..   ...                    ...      ...     ...          ...  ..     ...
# 795  719                Diancie     Rock   Fairy          600  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy          700  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost          600  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark          680  80     160
# 799  721              Volcanion     Fire   Water          600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.head(20)
# Out:
#      #                       Name Type 1  Type 2  Total Power  HP  Attack  \
# 0    1                  Bulbasaur  Grass  Poison          318  45      49
# 1    2                    Ivysaur  Grass  Poison          405  60      62
# 2    3                   Venusaur  Grass  Poison          525  80      82
# 3    3      VenusaurMega Venusaur  Grass  Poison          625  80     100
# 4    4                 Charmander   Fire     NaN          309  39      52
# 5    5                 Charmeleon   Fire     NaN          405  58      64
# 6    6                  Charizard   Fire  Flying          534  78      84
# 7    6  CharizardMega Charizard X   Fire  Dragon          634  78     130
# 8    6  CharizardMega Charizard Y   Fire  Flying          634  78     104
# 9    7                   Squirtle  Water     NaN          314  44      48
# 10   8                  Wartortle  Water     NaN          405  59      63
# 11   9                  Blastoise  Water     NaN          530  79      83
# ...

# %%
#df.loc[df['Name'].str.contains('(wee).*' ,flags= re.I ,regex=True)]

# %%
df['Name'].replace(to_replace=r'[wee Wee](.*)', value='FAR\g<1>', regex=True, inplace=True)

# %%
df.head(20)
# Out:
#      #                         Name Type 1  Type 2  Total Power  HP  Attack  \
# 0    1                    Bulbasaur  Grass  Poison          318  45      49
# 1    2                      Ivysaur  Grass  Poison          405  60      62
# 2    3                   VFARnusaur  Grass  Poison          525  80      82
# 3    3      VFARnusaurMega Venusaur  Grass  Poison          625  80     100
# 4    4                 CharmandFARr   Fire     NaN          309  39      52
# 5    5                 CharmFARleon   Fire     NaN          405  58      64
# 6    6                    Charizard   Fire  Flying          534  78      84
# 7    6  CharizardMFARga Charizard X   Fire  Dragon          634  78     130
# 8    6  CharizardMFARga Charizard Y   Fire  Flying          634  78     104
# 9    7                   SquirtlFAR  Water     NaN          314  44      48
# 10   8                  FARartortle  Water     NaN          405  59      63
# ...

# %%
new_df = pd.read_csv(r"C:\Users\famir\Desktop\Pokemon.csv", chunksize=5)
main_df = pd.DataFrame(columns=new_df.columns)

# %%
df_chunked
